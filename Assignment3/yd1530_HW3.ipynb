# %% [markdown]
# Q1: Create the following training datasets from the optdigits.tra set:
# X25: Randomly chosen N=25 instances from each class.
# X100:  Randomly chosen N=100 instances from each class.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, read_csv, to_numeric
from sklearn import cluster
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import math

# %%
train_data = pd.read_csv('/media/anuja/study/Anuja/MS/githubLibraries/MLprojects/Assignment3/optdigits.tra', sep=",")
train_data
# Out:
#       0  1   6  15  12  1.1  0.1  0.2  0.3  7  ...  0.21  0.22  0.23  6.3  \
# 0     0  0  10  16   6    0    0    0    0  7  ...     0     0     0   10
# 1     0  0   8  15  16   13    0    0    0  1  ...     0     0     0    9
# 2     0  0   0   3  11   16    0    0    0  0  ...     0     0     0    0
# 3     0  0   5  14   4    0    0    0    0  0  ...     0     0     0    4
# 4     0  0  11  16  10    1    0    0    0  4  ...     3     0     0   10
# ...  .. ..  ..  ..  ..  ...  ...  ...  ... ..  ...   ...   ...   ...  ...
# 3817  0  0   5  13  11    2    0    0    0  2  ...     0     0     0    8
# 3818  0  0   0   1  12    1    0    0    0  0  ...     0     0     0    0
# 3819  0  0   3  15   0    0    0    0    0  0  ...     0     0     0    4
# 3820  0  0   6  16   2    0    0    0    0  0  ...     0     0     0    5
# 3821  0  0   2  15  16   13    1    0    0  0  ...     0     0     0    4
#
#       14.1  7.4  1.3  0.24  0.25  0.26
# 0       16   15    3     0     0     0
# ...

# %%
# first get the all instances of each class and store them 
train_array = np.asarray(train_data)    
    
class0_all_train = train_array[train_array[:,64] == 0, :]
class1_all_train = train_array[train_array[:,64] == 1, :]
class2_all_train = train_array[train_array[:,64] == 2, :]
class3_all_train = train_array[train_array[:,64] == 3, :]
class4_all_train = train_array[train_array[:,64] == 4, :]
class5_all_train = train_array[train_array[:,64] == 5, :]
class6_all_train = train_array[train_array[:,64] == 6, :]
class7_all_train = train_array[train_array[:,64] == 7, :]
class8_all_train = train_array[train_array[:,64] == 8, :]
class9_all_train = train_array[train_array[:,64] == 9, :]

print(class0_all_train.shape)
print(class1_all_train.shape)
print(class2_all_train.shape)
print(class3_all_train.shape)
print(class4_all_train.shape)
print(class5_all_train.shape)
print(class6_all_train.shape)
print(class7_all_train.shape)
print(class8_all_train.shape)
print(class9_all_train.shape)
# Out:
# (375, 65)
# (389, 65)
# (380, 65)
# (389, 65)
# (387, 65)
# (376, 65)
# (377, 65)
# (387, 65)
# (380, 65)
# (382, 65)

# %%
# now get 25 instances of each class and store them
